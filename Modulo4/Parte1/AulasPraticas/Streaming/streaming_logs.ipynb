# %% [markdown]
# **Verificando se os arquivos estão nas pastas indicadas**

# %%
# %fs ls /FileStore/tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/Mall_Customers.csv</td><td>Mall_Customers.csv</td><td>4286</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_01_24d0c.json</td><td>d1995_07_01_24d0c.json</td><td>7451741</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_02_c3f44.json</td><td>d1995_07_02_c3f44.json</td><td>9572086</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_03_f99af.json</td><td>d1995_07_03_f99af.json</td><td>14125303</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_04_c5a7f.json</td><td>d1995_07_04_c5a7f.json</td><td>12030333</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_05_0f261.json</td><td>d1995_07_05_0f261.json</td><td>14662194</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_06_20619.json</td><td>d1995_07_06_20619.json</td><td>15557682</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_07_2dd8d.json</td><td>d1995_07_07_2dd8d.json</td><td>15279295</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_08_83302.json</td><td>d1995_07_08_83302.json</td><td>7033852</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_09_f75d3.json</td><td>d1995_07_09_f75d3.json</td><td>5589076</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_10_160a3.json</td><td>d1995_07_10_160a3.json</td><td>10616482</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_11_8800f.json</td><td>d1995_07_11_8800f.json</td><td>12486245</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_12_3091c.json</td><td>d1995_07_12_3091c.json</td><td>14080494</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_13_242b2.json</td><td>d1995_07_13_242b2.json</td><td>21989188</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_14_bab67.json</td><td>d1995_07_14_bab67.json</td><td>13780636</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_15_57e08.json</td><td>d1995_07_15_57e08.json</td><td>8057272</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_16_2ca03.json</td><td>d1995_07_16_2ca03.json</td><td>7171848</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_17_905a5.json</td><td>d1995_07_17_905a5.json</td><td>11897536</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_18_13b8b.json</td><td>d1995_07_18_13b8b.json</td><td>10569098</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_19_e2537.json</td><td>d1995_07_19_e2537.json</td><td>11515206</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_20_0f6d2.json</td><td>d1995_07_20_0f6d2.json</td><td>11049142</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_21_37a88.json</td><td>d1995_07_21_37a88.json</td><td>10475868</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_22_3b894.json</td><td>d1995_07_22_3b894.json</td><td>6028420</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_23_8d606.json</td><td>d1995_07_23_8d606.json</td><td>5620028</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_24_bcae5.json</td><td>d1995_07_24_bcae5.json</td><td>10433367</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_25_22c14.json</td><td>d1995_07_25_22c14.json</td><td>9883055</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_26_8a504.json</td><td>d1995_07_26_8a504.json</td><td>9087395</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_27_32f69.json</td><td>d1995_07_27_32f69.json</td><td>10172162</td></tr><tr><td>dbfs:/FileStore/tables/d1995_07_28_8d6d2.json</td><td>d1995_07_28_8d6d2.json</td><td>6206927</td></tr><tr><td>dbfs:/FileStore/tables/designation.json</td><td>designation.json</td><td>400</td></tr><tr><td>dbfs:/FileStore/tables/digitsNew.csv</td><td>digitsNew.csv</td><td>76775041</td></tr><tr><td>dbfs:/FileStore/tables/iris_bezdekIris.csv</td><td>iris_bezdekIris.csv</td><td>4551</td></tr><tr><td>dbfs:/FileStore/tables/regressaoLinear.csv</td><td>regressaoLinear.csv</td><td>564</td></tr><tr><td>dbfs:/FileStore/tables/salary.json</td><td>salary.json</td><td>361</td></tr><tr><td>dbfs:/FileStore/tables/temperature.csv</td><td>temperature.csv</td><td>13971171</td></tr><tr><td>dbfs:/FileStore/tables/transport_nodes_7c826.csv</td> ...

# %% [markdown]
# ** Criando o diretório de saída**

# %%
#define o caminho para a saida
output_path = "/tmp/pydata/Streaming/output/"
dbutils.fs.rm(output_path,True)
dbutils.fs.mkdirs(output_path)

#define o caminho para o checkpoint, necessário para utilizar algumas funçoes e garantir tolerância a falhas
checkpoint_path = "/tmp/pydata/Streaming/checkpoint/"
dbutils.fs.rm(checkpoint_path,True)
dbutils.fs.mkdirs(checkpoint_path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: True</div>

# %% [markdown]
# **Definindo o esquema para o dataset**

# %%
from pyspark.sql.types import StructType, IntegerType, StringType, LongType, StructField, TimestampType
schema_entrada =  StructType([
    StructField("bytes", LongType()),
    StructField("host", StringType()),
    StructField("http_reply", IntegerType()),
    StructField("request", StringType()),
    StructField("timestamp", StringType())
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Criando o dataframe estático

# %%
logsDirectoryStatic = "/FileStore/tables/d1995_07_01_24d0c.json" #define o local onde os arquivos estão armazenados
static = spark.read.json(logsDirectoryStatic, schema_entrada)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Verificando se o dataframe é estático ou streaming

# %%
static.isStreaming
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: False</div>

# %%
#print do schema
static.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- bytes: long (nullable = true)
# -- host: string (nullable = true)
# -- http_reply: integer (nullable = true)
# -- request: string (nullable = true)
# -- timestamp: string (nullable = true)
#
# </div>

# %% [markdown]
# **Conhecendo o banco de dados**

# %%
#apresenta as primeiras 5 linhas do dataframe
static.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------------------+----------+--------------------+--------------------+
# bytes|                host|http_reply|             request|           timestamp|
# +-----+--------------------+----------+--------------------+--------------------+
#  6245|        199.72.81.55|       200|GET /history/apol...|1995-07-01T06:00:...|
#  3985|unicomp6.unicomp.net|       200|GET /shuttle/coun...|1995-07-01T06:00:...|
#  4085|      199.120.110.21|       200|GET /shuttle/miss...|1995-07-01T06:00:...|
#     0|  burger.letters.com|       304|GET /shuttle/coun...|1995-07-01T06:00:...|
#  4179|      199.120.110.21|       200|GET /shuttle/miss...|1995-07-01T06:00:...|
# +-----+--------------------+----------+--------------------+--------------------+
# only showing top 5 rows
#
# </div>

# %%
#contando a quantidade de linhas existente no dataframe
(static.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: 45657</div>

# %%
#retorna o valor médio de bytes gerados pelas consultas
from pyspark.sql.functions import avg
static.select(avg("bytes")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
#        avg(bytes)|
# +-----------------+
# 25213.30665615349|
# +-----------------+
#
# </div>

# %%
#seleciona a quantidade de valores diferentes existentes na coluna host
from pyspark.sql.functions import asc, col, desc

grupo_host_distintos = static.select("host").distinct().sort(col("host").asc())
grupo_host_distintos.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------+
#            host|
# +---------------+
#  128.102.86.254|
#  128.138.177.51|
#  128.147.44.103|
#   128.148.15.20|
#  128.158.21.103|
#  128.158.54.114|
# 128.159.122.119|
#  128.159.132.53|
# 128.159.154.142|
#   128.163.80.98|
# 128.171.118.102|
# 128.187.140.171|
#  128.194.252.50|
#  128.220.40.121|
#  128.220.56.135|
#  128.250.245.53|
# 128.252.230.210|
#   128.253.21.23|
#   128.59.161.66|
#   128.95.200.71|
# +---------------+
# only showing top 20 rows
#
# </div>

# %%
#cria a tabela para utilizar a consulta via SQL
static.createOrReplaceTempView("grupo_1")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT DISTINCT host
  FROM grupo_1
ORDER BY host
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
.212</td></tr><tr><td>138.103.104.243</td></tr><tr><td>138.9.200.82</td></tr><tr><td>139.121.119.19</td></tr><tr><td>139.133.213.161</td></tr><tr><td>139.169.183.42</td></tr><tr><td>139.169.29.37</td></tr><tr><td>139.169.30.9</td></tr><tr><td>139.169.71.53</td></tr><tr><td>139.230.203.30</td></tr><tr><td>140.128.120.202</td></tr><tr><td>140.168.249.1</td></tr><tr><td>140.186.64.163</td></tr><tr><td>141.31.25.61</td></tr><tr><td>142.158.109.27</td></tr><tr><td>142.170.43.6</td></tr><tr><td>142.31.49.194</td></tr><tr><td>142.32.102.46</td></tr><tr><td>142.51.12.202</td></tr><tr><td>142.74.30.10</td></tr><tr><td>144.16.74.75</td></tr><tr><td>144.170.245.42</td></tr><tr><td>144.191.237.17</td></tr><tr><td>144.96.210.67</td></tr><tr><td>144.96.228.13</td></tr><tr><td>146.124.246.10</td></tr><tr><td>146.63.242.210</td></tr><tr><td>147.148.3.165</td></tr><tr><td>147.148.30.208</td></tr><tr><td>147.149.230.144</td></tr><tr><td>147.151.16.204</td></tr><tr><td>147.31.254.131</td></tr><tr><td>147.35.241.3</td></tr><tr><td>148.202.3.244</td></tr><tr><td>148.202.9.5</td></tr><tr><td>148.207.36.23</td></tr><tr><td>148.216.5.20</td></tr><tr><td>148.225.80.35</td></tr><tr><td>148.241.10.249</td></tr><tr><td>149.123.74.30</td></tr><tr><td>149.171.160 ...

# %% [markdown]
# **Criando o modelo dinâmico (Streaming)**

# %%
#importando bibliotecas
from pyspark.sql.functions import input_file_name, current_timestamp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#define o caminho para a entrada dos arquivos de log
logsDirectoryStreaming= "/FileStore/tables/*.json" #define o local onde os arquivos estão armazenados
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Definindo o modelo de Streaming
streamingDF = (
  spark
  .readStream 
  .schema(schema_entrada) #esquema definido para a coleta dos dados presentes em JSON
  .option("maxFilesPerTrigger", 1)  #mantém a leitura de apenas um arquivo por batch, para manter mais lenta a coleta
  .json(logsDirectoryStreaming) #define o local a ser pesquisado para obter os dados
  .withColumn("INPUT_FILE_NAME", input_file_name()) #cria a coluna para armazenar o nome do arquivo o qual o dado foi lido
  .withColumn("PROCESSED_TIME", current_timestamp()) #adiciona o tempo em que o dado foi processado
  .withWatermark("PROCESSED_TIME", "1 minute") #adiciona a janela de tempo para a leitura (marca d'água)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# define a saída (sink)
query = (
  streamingDF
  .writeStream
  .format("parquet") #define o formato do arquivo a ser utilizado (parquet)
  .option("path", output_path) #define o local onde os arquivos devem ser adicionados
  .option("checkpointLocation", checkpoint_path) # define o checkpoint para garantir a tolerãncia a falhas
  .outputMode("append") # define o modo de saída para os dados
  .queryName("logs") #define o nome para a consulta
  .trigger(processingTime='5 seconds') #define o "tempo de processamento" para cada dado recebido
  .start() #inicia o processamento em streaming
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Visualizando as Saídas em Tempo Real**

# %%
#cria a tabela para realizar as consultas sobre os dados que estãos sendo lidos
streamingDF.createOrReplaceTempView("logs_table_in")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql select COUNT(*) from logs_table_in where http_reply = 200
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>1701451</td></tr></tbody></table></div>

# %% [markdown]
# **Realizando a leitura dos dados na pasta de saída**

# %%
#define o esquema para a leitura dos dados que estão na pasta de saída
#esquema modificado para que os dados possam ser adicionados ao formato de saída
schemaSaida = (
  StructType()
  .add("timestamp", TimestampType()) #event time 
  .add("bytes", LongType())
  .add("host", StringType())
  .add("http_reply", IntegerType())
  .add("request", StringType())
  .add("INPUT_FILE_NAME", StringType()) #Nome do arquivo em que o dado do sensor foi criado 
  .add("PROCESSED_TIME", TimestampType()) #timestamp para o processamento dos dados
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.conf.set("spark.sql.shuffle.partitions", "1") #define valor para os shuffles

#define a configuração para a leitura
saidasLogs = (
  spark.readStream
  .schema(schemaSaida) #lê os dados através do esquema definido para a transformação
  .format("parquet") #define o formato dos aquivos de leitura
  .option("maxFilesPerTrigger", 1) #Mantém a leitura dos dados como 1 arquivo para a demonstração ser mais lenta
  .load(output_path) # indica de onde o arquivo será lido 
  .withWatermark("PROCESSED_TIME", "1 minute") #define a janela de tempo para a leitura dos dados
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# define a tabela temporária para que seja possível realizar as consultas sobre os dados utilizando o SQL 
saidasLogs.createOrReplaceTempView("logs_table_out")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql select COUNT(*) from logs_table_out
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>1126329</td></tr></tbody></table></div>

# %% [markdown]
# Valor médio para cada host

# %%
# %sql
SELECT host, AVG(bytes) as media_bytes FROM logs_table_out GROUP BY host
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host</th><th>media_bytes</th></tr></thead><tbody><tr><td>204.138.186.16</td><td>27859.46153846154</td></tr><tr><td>gillside.bfsec.bt.co.uk</td><td>11574.5</td></tr><tr><td>162.127.2.238</td><td>27071.666666666668</td></tr><tr><td>137.98.196.2</td><td>6662.473684210527</td></tr><tr><td>165.113.8.64</td><td>46885.75</td></tr><tr><td>msp7-9.nas.mr.net</td><td>14373.8</td></tr><tr><td>ad03-010.compuserve.com</td><td>188355.0</td></tr><tr><td>startide.odyssey.com.au</td><td>9911.47619047619</td></tr><tr><td>161.142.162.11</td><td>2497.5</td></tr><tr><td>b17.ppp.mo.net</td><td>5610.25</td></tr><tr><td>ppp3_171.bekkoame.or.jp</td><td>11571.25</td></tr><tr><td>hp1.ep.cursci.com</td><td>9704.25</td></tr><tr><td>srv1s1.saglac.qc.ca</td><td>8790.384615384615</td></tr><tr><td>itd42.saic.com</td><td>19089.983695652172</td></tr><tr><td>janus.pec.co.nz</td><td>31485.25</td></tr><tr><td>salud.gsfc.nasa.gov</td><td>3878.0</td></tr><tr><td>ssmith.wff.nasa.gov</td><td>48070.333333333336</td></tr><tr><td>sebastion.sa.camtech.com.au</td><td>6815.25</td></tr><tr><td>dial2-27.midwest.net</td><td>16503.428571428572</td></tr><tr><td>sabre5.sasknet.sk.ca</td><td>0.0</td></tr><tr><td>xtwa5.ess.harris.com</td><td>8453.60606060606</td></tr><tr><td>cyberialon1.easynet.co.uk</td><td>6061.222222222223</td></tr><tr><td>p18-31.dialup.uvic.ca</td><td>27405.97142857143</td></tr><tr><td>medline-178.rfhsm.ac.uk</td><td
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>request</th></tr></thead><tbody><tr><td>GET /shuttle/technology/sts-newsref/overview.txt   HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-71/images/KSC-95EC-0916.jpg</td></tr><tr><td>GET /htbin/wais.pl?LIDAR HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?107,111 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/fr?43,43?19,457 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?397,152 HTTP/1.0</td></tr><tr><td>GET /history/gemini/gemini-viii/gemini-viii-patch-small.gif HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?226,199 HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?Jack+Swigert HTTP/1.0</td></tr><tr><td>GET /statistics/1993/Dec/Dec93_request.gif HTTP/1.0</td></tr><tr><td>GET /biomed/env.html HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?369,272 HTTP/1.0</td></tr><tr><td>GET /news/sci.space.news/1988   HTTP/1.0</td></tr><tr><td>GET /biomed/history/history.html HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-32/images/90HC459.GIF HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?382,275 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/fr?328,165 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?114,204 HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?hubble+images HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?320,280 HTTP/1.0</td></tr><tr><td>GET /history/apollo/as-203/ HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-61/movies/ HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-45/sts-45-press-kit.txt HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?115,114 HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-70/news/shuttle-status-5-25.txt HTTP/1.0</td></tr><tr><td>GET /news/sci.space.news/2343 HTTP/1.0</td></tr><tr><td>GET /facilities/vpf.html HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?2+line HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?98,112 HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?present+location HTTP/1.0</td></tr><tr><td>GET /persons/astronauts/m-to-p/MullaneRM.txt HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?297,210 HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?E-mail+addresses HTTP/1.0</td></tr><tr><td>GET /news/sci.space.news/181 HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?shortwave HTTP/1.0</td></tr><tr><td>GET /elv/TITAN/mars3s.jpg HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?92,137 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?356,232 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?388,278 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?342,162 HTTP/1.0</td></tr><tr><td>HEAD /images/KSC-logosmall.gif HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?103,171 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?104,186 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?103,269 HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-34/sounds/ HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?104,108 HTTP/1.0</td></tr><tr><td>GET / history/apollo/apollo-13 HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?aluminium+oxide HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?380,265 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/fr?43,43 HTTP/1.0</td></tr><tr><td>GET /history/gemini/gemini-xii/gemini-xii-info.html HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?376,272 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?105,199 HTTP/1.0</td></tr><tr><td>GET /history/apollo/as-202/news/ HTTP/1.0</td></tr><tr><td>GET /shuttle/missions/sts-26/sts-26-press-kit.txt HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?Galileo%2FIda HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?92,278 HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?528,228 HTTP/1.0</td></tr><tr><td>GET /htbin/wais.pl?realtime HTTP/1.0</td></tr><tr><td>GET /cgi-bin/imagemap/countdown?106,130 HTTP/1.0</td></tr><tr><td>GET /images/cr ...
